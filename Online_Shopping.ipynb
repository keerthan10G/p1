# %% [markdown]
# Import Required Libraies

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as pl
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Import Data

# %%
df=pd.read_excel("file.xlsx")

# %% [markdown]
# Explore Dataset

# %%
df.head(5)
# Out:
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
# 3           3     17850.0      M  Chicago           12.0         16699.0
# 4           4     17850.0      M  Chicago           12.0         16700.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# 3       2019-01-01  GGOENEBQ079099
# 4       2019-01-01  GGOENEBJ079499
#
#                                  Product_Description Product_Category  ...  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA  ...
# ...

# %%
df.size
# Out:
# 1165010

# %%
df.shape
# Out:
# (52955, 22)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'Gender', 'Location', 'Tenure_Months',
#        'Transaction_ID', 'Transaction_Date', 'Product_SKU',
#        'Product_Description', 'Product_Category', 'Quantity', 'Avg_Price',
#        'Delivery_Charges', 'Coupon_Status', 'GST', 'Date', 'Offline_Spend',
#        'Online_Spend', 'Month', 'Coupon_Code', 'Discount_pct', 'sales'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52955 entries, 0 to 52954
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           52955 non-null  int64
#  1   CustomerID           52924 non-null  float64
#  2   Gender               52924 non-null  object
#  3   Location             52924 non-null  object
#  4   Tenure_Months        52924 non-null  float64
#  5   Transaction_ID       52924 non-null  float64
#  6   Transaction_Date     52924 non-null  datetime64[ns]
#  7   Product_SKU          52924 non-null  object
#  8   Product_Description  52924 non-null  object
#  9   Product_Category     52955 non-null  object
#  10  Quantity             52924 non-null  float64
#  11  Avg_Price            52924 non-null  float64
#  12  Delivery_Charges     52924 non-null  float64
#  13  Coupon_Status        52924 non-null  object
#  14  GST                  52924 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0   CustomerID  Tenure_Months  Transaction_ID      Quantity  \
# count  52955.000000  52924.00000   52924.000000    52924.000000  52924.000000
# mean   26477.000000  15346.70981      26.127995    32409.825675      4.497638
# std    15286.936089   1766.55602      13.478285     8648.668977     20.104711
# min        0.000000  12346.00000       2.000000    16679.000000      1.000000
# 25%    13238.500000  13869.00000      15.000000    25384.000000      1.000000
# 50%    26477.000000  15311.00000      27.000000    32625.500000      1.000000
# 75%    39715.500000  16996.25000      37.000000    39126.250000      2.000000
# max    52954.000000  18283.00000      50.000000    48497.000000    900.000000
#
#           Avg_Price  Delivery_Charges           GST  Offline_Spend  \
# count  52924.000000      52924.000000  52924.000000   52924.000000
# mean      52.237646         10.517630      0.137462    2830.914141
# ...

# %% [markdown]
# Data cleaning and organising

# %%
df.isna().sum()
# Out:
# Unnamed: 0               0
# CustomerID              31
# Gender                  31
# Location                31
# Tenure_Months           31
# Transaction_ID          31
# Transaction_Date        31
# Product_SKU             31
# Product_Description     31
# Product_Category         0
# Quantity                31
# Avg_Price               31
# Delivery_Charges        31
# Coupon_Status           31
# GST                     31
# Date                    31
# Offline_Spend           31
# Online_Spend            31
# Month                    0
# Coupon_Code            400
# Discount_pct           400
# sales                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.tail(50)
# Out:
#        Unnamed: 0  CustomerID Gender    Location  Tenure_Months  \
# 52905       52905     15039.0      F     Chicago           19.0
# 52906       52906     18016.0      F     Chicago           16.0
# 52907       52907     18016.0      F     Chicago           16.0
# 52908       52908     17890.0      F     Chicago           27.0
# 52909       52909     14159.0      F  California           13.0
# 52910       52910     14577.0      M  California           36.0
# 52911       52911     14667.0      F  California           30.0
# 52912       52912     16442.0      F    New York           46.0
# 52913       52913     14524.0      F    New York           15.0
# 52914       52914     14031.0      F     Chicago           17.0
# 52915       52915     15002.0      M     Chicago           41.0
# 52916       52916     15002.0      M     Chicago           41.0
# 52917       52917     15002.0      M     Chicago           41.0
# 52918       52918     15002.0      M     Chicago           41.0
# ...

# %%
df=df.drop(["Unnamed: 0"],axis=1)
df
# Out:
#        CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M  Chicago           12.0         16679.0
# 1         17850.0      M  Chicago           12.0         16680.0
# 2         17850.0      M  Chicago           12.0         16696.0
# 3         17850.0      M  Chicago           12.0         16699.0
# 4         17850.0      M  Chicago           12.0         16700.0
# ...           ...    ...      ...            ...             ...
# 52950         NaN    NaN      NaN            NaN             NaN
# 52951         NaN    NaN      NaN            NaN             NaN
# 52952         NaN    NaN      NaN            NaN             NaN
# 52953         NaN    NaN      NaN            NaN             NaN
# 52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# 0           2019-01-01  GGOENEBJ079499
# 1           2019-01-01  GGOENEBJ079499
# 2           2019-01-01  GGOENEBQ078999
# ...

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# CustomerID             0
# Gender                 0
# Location               0
# Tenure_Months          0
# Transaction_ID         0
# Transaction_Date       0
# Product_SKU            0
# Product_Description    0
# Product_Category       0
# Quantity               0
# Avg_Price              0
# Delivery_Charges       0
# Coupon_Status          0
# GST                    0
# Date                   0
# Offline_Spend          0
# Online_Spend           0
# Month                  0
# Coupon_Code            0
# Discount_pct           0
# sales                  0
# dtype: int64

# %%
df.shape
# Out:
# (52524, 21)

# %%
df.agg(["mean","median"])
# Out:
#           CustomerID  Tenure_Months  Transaction_ID  \
# mean    15345.347213      26.140393    32445.093367
# median  15311.000000      27.000000    32678.000000
#
#                     Transaction_Date  Quantity  Avg_Price  Delivery_Charges  \
# mean   2019-07-06 05:10:50.582590720  4.500171  52.429089         10.476922
# median 2019-07-14 00:00:00.000000000  1.000000  16.990000          6.000000
#
#              GST  Offline_Spend  Online_Spend    Month  Discount_pct  \
# mean    0.137433    2832.428985   1894.216417  6.66581     19.953164
# median  0.180000    3000.000000   1837.870000  7.00000     20.000000
#
#             sales
# mean    62.906011
# median  27.210000

# %%
df.corr()
# Out:
#                   CustomerID  Tenure_Months  Transaction_ID  Quantity  \
# CustomerID          1.000000      -0.023816       -0.091303 -0.008158
# Tenure_Months      -0.023816       1.000000        0.021634  0.006807
# Transaction_ID     -0.091303       0.021634        1.000000 -0.028466
# Quantity           -0.008158       0.006807       -0.028466  1.000000
# Avg_Price           0.004321      -0.000916        0.124854 -0.114066
# Delivery_Charges   -0.005956      -0.014535       -0.084902  0.191787
# GST                -0.000050      -0.001652       -0.099080 -0.028219
# Offline_Spend      -0.004118       0.040147        0.200343 -0.004583
# Online_Spend       -0.017440       0.025451        0.165640  0.010647
# Month              -0.090152       0.018878        0.995521 -0.027297
# Discount_pct        0.000337       0.029703        0.241759 -0.011381
# sales               0.002494      -0.005231        0.098002 -0.055532
#
# ...

# %%
df.drop(["Transaction_ID","Tenure_Months","sales","Product_SKU","Product_Description"],axis=1,inplace=True)
df.shape
# Out:
# (52524, 16)

# %% [markdown]
# Data Analysis and data visualization

# %%
Gender_value=df["Gender"].value_counts()

# %%
pl.style.context("seaborn-v0_8-bright")
pl.figure(figsize=(4,4),dpi=100)
pl.pie([Gender_value[0],Gender_value[1]],colors=['#c56dc9','#6da1c9'],autopct="%.1f%%",pctdistance=0.7,explode=[0.03,0.03],labels=["Female","Male"],textprops={'font':'arial','fontsize':14})
pl.title("How many female and male are There ?",color='#d62727',fontsize=18,fontstyle='oblique',fontweight='bold')
pl.savefig("how_many_male.png",dpi=300,bbox_inches='tight')
pl.show()

# %%
df.head(4)
# Out:
#    CustomerID Gender Location Transaction_Date Product_Category  Quantity  \
# 0     17850.0      M  Chicago       2019-01-01         Nest-USA       1.0
# 1     17850.0      M  Chicago       2019-01-01         Nest-USA       1.0
# 2     17850.0      M  Chicago       2019-01-01         Nest-USA       2.0
# 3     17850.0      M  Chicago       2019-01-01         Nest-USA       1.0
#
#    Avg_Price  Delivery_Charges Coupon_Status  GST      Date  Offline_Spend  \
# 0     153.71               6.5          Used  0.1  1/1/2019         4500.0
# 1     153.71               6.5          Used  0.1  1/1/2019         4500.0
# 2     122.77               6.5      Not Used  0.1  1/1/2019         4500.0
# 3      81.50               6.5       Clicked  0.1  1/1/2019         4500.0
#
#    Online_Spend  Month Coupon_Code  Discount_pct
# 0        2424.5      1      ELEC10          10.0
# 1        2424.5      1      ELEC10          10.0
# 2        2424.5      1      ELEC10          10.0
# ...

# %%
pl.figure(figsize=(20,8),dpi=300)
pl.style.use('seaborn-v0_8-bright')
df[["Location","Product_Category"]].groupby("Location").count().plot(kind='bar',color='#4934eb')
#pl.text(0.9,18300,"*",color='r')
pl.ylabel("No of product sold",color="black",fontdict={'fontstyle':'italic','fontsize':15}) 
pl.xlabel("Location",color="black",rotation=0,fontdict={'fontstyle':'italic','fontsize':15}) 
pl.title("No. of Products Sold in Diffrent Regions",fontdict={'fontstyle':'oblique','fontsize':18},color='#d62727',fontweight='bold')
pl.xticks(color="r",rotation=0,fontsize=10)
pl.legend().remove()
pl.yticks(color="black",rotation=45)
pl.savefig("noofproducts.png",dpi=300,bbox_inches='tight')
pl.show()
pl.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
val=df["Product_Category"].value_counts()
l=[]
for i in val:
    if(i>3000):
       l.append(i)
ser=pd.Series(l)
ser
# Out:
# 0    18126
# 1    14013
# 2     6513
# 3     3483
# 4     3092
# dtype: int64

# %%
from  matplotlib.gridspec import GridSpec

pl.style.context('seaborn-v0_8.bright')
gs=GridSpec(2,2)
fig=pl.figure(figsize=(6,6),dpi=200)
fig1=pl.figure(figsize=(5,6),dpi=200)
fig2=pl.figure(figsize=(5,4),dpi=200)

ax1=fig.add_subplot(gs[0,0])
l=[]
for i in range(0,5):
    l.append(0.05)
ax1.set_title("Most Selled products",fontsize=15,fontstyle="oblique",color='#d62727',fontweight='bold')
ax1.pie(ser,labels=["Apparel","Nest-USA","Office","Drinkware","Lifestyle"],explode=l,autopct="%.1f%%",textprops={'font':'arial','fontsize':10},pctdistance=0.7)
fig.tight_layout()
fig.savefig("mostsold.png",dpi=300,bbox_inches='tight')

ax2=fig1.add_subplot(gs[1,1])
ax2.bar(df[df["Product_Category"]=="Apparel"]["Product_Category"],df[df["Product_Category"]=="Apparel"]["Discount_pct"].mean(),color="#4287f5",width=0.5)
ax2.bar(df[df["Product_Category"]=="Nest-USA"]["Product_Category"],df[df["Product_Category"]=="Nest-USA"]["Discount_pct"].mean(),color="#42f5e9",width=0.5)
ax2.bar(df[df["Product_Category"]=="Office"]["Product_Category"],df[df["Product_Category"]=="Office"]["Discount_pct"].mean(),color="#e6e207",width=0.5)
ax2.set_title("Average Discounts on Products",fontsize=10,fontstyle="oblique",color='#d62727',fontweight='bold')
ax2.set_xlabel("Top 3 Sold products",color="#a832a6",fontdict={'fontstyle':'italic','fontsize':10})
ax2.set_ylabel("Discount %",color="#a832a6",fontdict={'fontstyle':'italic','fontsize':10})
ax2.set_yticks([0,10,20,30])
fig1.tight_layout()
fig1.savefig("mostsold1.png",dpi=300,bbox_inches='tight')


ax3=fig2.add_subplot(gs[1,0])
ax3.bar(df[df["Product_Category"]=="Apparel"]["Product_Category"],df[df["Product_Category"]=="Apparel"]["Delivery_Charges"].mean(),color="#4287f5",width=0.5)
ax3.bar(df[df["Product_Category"]=="Nest-USA"]["Product_Category"],df[df["Product_Category"]=="Nest-USA"]["Delivery_Charges"].mean(),color="#42f5e9",width=0.5)
ax3.bar(df[df["Product_Category"]=="Office"]["Product_Category"],df[df["Product_Category"]=="Office"]["Delivery_Charges"].mean(),color="#e6e207",width=0.5)
ax3.set_title("Average Delivery charges on Product",fontsize=10,fontstyle="oblique",color='#d62727',fontweight='bold')
ax3.set_xlabel("Top 3 Sold products",color="#a832a6",fontdict={'fontstyle':'italic','fontsize':10})
ax3.set_ylabel("Delivery Charges",color="#a832a6",fontdict={'fontstyle':'italic','fontsize':10})
fig2.tight_layout()
fig2.savefig("mostsold2.png",dpi=300,bbox_inches='tight')

pl.show()

# %%
pl.style.use("seaborn-v0_8-bright")
pl.hist(df.Transaction_Date,rwidth=0.9,bins=18,)
pl.title("",fontsize=15,fontstyle="oblique",color='#d62727')
pl.xlabel("Date of Transcations",color="black",fontdict={'fontstyle':'italic','fontsize':15})
pl.ylabel("No. of Trancstions",color="black",fontdict={'fontstyle':'italic','fontsize':15})
pl.title("Date wise Trancations",fontdict={'fontstyle':'oblique','fontsize':20},color='#d62727',fontweight='bold')
pl.xticks(rotation=45,color='r')
pl.yticks(color='black')
pl.savefig("Trnacations.png",dpi=300,bbox_inches='tight')
pl.show()

# %%
pl.style.use('seaborn-v0_8')
pl.figure(figsize=(4.5,4.5),dpi=100)
df.Coupon_Status.value_counts().plot(kind='pie',autopct="%.1f%%",textprops={'font':'arial','fontsize':18},explode=[0.01,0.01,0.01],pctdistance=0.7,legend=False,colors=['#c2fce8','#d7c2fc','r'])
pl.title("Coupons Status",fontdict={'fontstyle':'oblique','fontsize':20},color='#d62727',fontweight='bold')

pl.savefig("Coupons.png",dpi=300,bbox_inches='tight')
pl.show()

# %%
df.head()
# Out:
#    CustomerID Gender Location Transaction_Date Product_Category  Quantity  \
# 0     17850.0      M  Chicago       2019-01-01         Nest-USA       1.0
# 1     17850.0      M  Chicago       2019-01-01         Nest-USA       1.0
# 2     17850.0      M  Chicago       2019-01-01         Nest-USA       2.0
# 3     17850.0      M  Chicago       2019-01-01         Nest-USA       1.0
# 4     17850.0      M  Chicago       2019-01-01         Nest-USA       1.0
#
#    Avg_Price  Delivery_Charges Coupon_Status  GST      Date  Offline_Spend  \
# 0     153.71               6.5          Used  0.1  1/1/2019         4500.0
# 1     153.71               6.5          Used  0.1  1/1/2019         4500.0
# 2     122.77               6.5      Not Used  0.1  1/1/2019         4500.0
# 3      81.50               6.5       Clicked  0.1  1/1/2019         4500.0
# 4     153.71               6.5       Clicked  0.1  1/1/2019         4500.0
#
#    Online_Spend  Month Coupon_Code  Discount_pct
# ...

# %%
pl.style.use('seaborn-v0_8-colorblind')
df["GST"].value_counts().plot(kind='bar',color='#fcba03')
pl.title("Rate of GST",fontdict={'fontstyle':'oblique','fontsize':20},color='#d62727',fontweight='bold')
pl.xticks(color="r",rotation=0,fontsize=10)
pl.yticks(color="black",rotation=0,fontsize=10)
pl.xlabel("GST",color='black',fontsize=20)
pl.ylabel("Count of GST",color='black',fontsize=15)
pl.savefig("rateofGST.png",dpi=300,bbox_inches='tight')
pl.show()

# %%
pl.style.use('seaborn-v0_8-bright')
gs=GridSpec(1,2)
fig1=pl.figure(figsize=(10,4),dpi=200)
fig2=pl.figure(figsize=(5,5),dpi=200)
ax1=fig1.add_subplot(gs[0,0])
ax2=fig2.add_subplot(gs[0,1])

ax1.scatter(df["Offline_Spend"],df["Month"],alpha=0.6,label="Offline")
ax1.scatter(df["Online_Spend"],df["Month"],alpha=0.6,label="Online")
ax1.legend()
ax1.set_title("Online Vs Offline",fontsize=17,fontstyle="oblique",color='#d62727',fontweight='bold')
ax1.set_xlabel("Amount Spend",color="#a832a6",fontdict={'fontstyle':'italic','fontsize':13})
ax1.set_ylabel("Month",color="#a832a6",fontdict={'fontstyle':'italic','fontsize':13})
fig1.savefig("ooscatter.png",dpi=300,bbox_inches='tight')
fig1.tight_layout()

ax2.pie([df["Online_Spend"].sum(),df["Offline_Spend"].sum()],labels=["Online","Offline"],explode=[0.01,0.01],autopct="%.1f%%",colors=["#b3b3b3","#09d9bd"],textprops={'font':'arial','fontsize':8},pctdistance=0.7)
ax2.set_title("Percentage Wise Online and Offline",fontsize=9,fontstyle="oblique",color='#d62727',fontweight='bold')
fig2.savefig("oopie.png",dpi=300,bbox_inches='tight')
pl.show()

# %%
pl.style.use('seaborn-v0_8-bright')
pl.bar("Apparel",df[df.Product_Category=="Apparel"]["Product_Category"].count(),label="Apparel")
pl.bar("Nest-USA",df[df.Product_Category=="Nest-USA"]["Product_Category"].count(),label="Nest-USA")
pl.bar("Housewares",df[df.Product_Category=="Housewares"]["Product_Category"].count(),label="Housewares")
pl.bar("Android",df[df.Product_Category=="Android"]["Product_Category"].count(),label="Android")
pl.title("Different Category Of Products Are Sold",fontdict={'fontstyle':'oblique','fontsize':20},color='#d62727',fontweight='bold')
pl.xticks(color="r",rotation=0,fontsize=10)
pl.yticks(color="black",rotation=0,fontsize=10)
pl.legend()
pl.xlabel("Category",color='black',fontsize=20)
pl.ylabel("Count of Products",color='black',fontsize=15)
pl.savefig("different.png",dpi=300,bbox_inches='tight')
pl.show()

# %%
pl.style.use('seaborn-v0_8-whitegrid')
pl.figure(figsize=(5.5,4.5),dpi=100)
house=df[df["Product_Category"]=="Housewares"]["Delivery_Charges"].mean()
pl.hist(house,bins=1,label="Housewares")
pl.hist(df[df["Product_Category"]=="Apparel"]["Delivery_Charges"].mean(),bins=1,label="Apparel")
pl.hist(df[df["Product_Category"]=="Nest-USA"]["Delivery_Charges"].mean(),bins=1,label="Nest-USA")
pl.hist(df[df["Product_Category"]=="Accessories"]["Delivery_Charges"].mean(),bins=1,label="Accessories")
pl.hist(df[df["Product_Category"]=="Nest-Canada"]["Delivery_Charges"].mean(),bins=1,label="Nest-Canada")
x=np.arange(0,19)
pl.title("Most Selled  Vs Less Selled products",fontdict={'fontstyle':'oblique','fontsize':15},color='#d62727',fontweight='bold')
pl.xticks(x,color="r",rotation=0,fontsize=10)
pl.yticks(color="black",rotation=0,fontsize=10)
pl.xlabel("Average Delivery Charges",color='black',fontsize=15)
pl.ylabel("Frequency",color='black',fontsize=15)
pl.legend()
pl.savefig("moreselldhist.png",dpi=300,bbox_inches='tight')
pl.show()

# %%
pl.style.use('seaborn-v0_8-darkgrid')
pl.figure(figsize=(10,7))
pl.scatter(df[df["Gender"]=="F"]["Month"],df[df["Gender"]=="F"]["Online_Spend"],label='Female',alpha=0.7,marker='*',c='#e802c6',s=70)
pl.scatter(df[df["Gender"]=="M"]["Month"],df[df["Gender"]=="M"]["Online_Spend"],label='Male',alpha=0.7,s=20,c='#fcba03')
pl.title("Month Wise Male and Female Online Spend",fontdict={'fontstyle':'oblique','fontsize':20},color='#d62727',fontweight='bold')
d=np.arange(0,13)
pl.xticks(d,rotation=0,fontsize=10)
pl.yticks(color="black",rotation=0,fontsize=10)
pl.xlabel("Months",color='black',fontsize=15)
pl.ylabel("Online Spend",color='black',fontsize=15)
pl.legend(loc='upper center')
pl.savefig("monthwisemalevsfemale.png",dpi=300,bbox_inches='tight')
pl.show()

# %%
df[df["Gender"]=="F"]["Online_Spend"].mean()
# Out:
# 1901.0450828577534

# %%
df[df["Gender"]=="M"]["Online_Spend"].mean()
# Out:
# 1882.891070000506

# %%
pl.style.context("seaborn-v0_8-bright")
pl.figure(figsize=(8,6),dpi=200)
val=np.arange(len(df.Month))
width=0.4
pl.bar(df.Month,df.Offline_Spend,width,color="#17ffe8",label="Offline")
pl.bar(df.Month+0.4,df.Online_Spend,width,color="#cc89",label="Online")
pl.title("Online and Offline Spend in each Months",fontdict={'fontstyle':'oblique','fontsize':15},color='#d62727',fontweight='bold')
pl.xticks(df.Month,color="r",rotation=0,fontsize=10)
pl.yticks(color="black",rotation=0,fontsize=10)
pl.xlabel("Months",color='black',fontsize=15)
pl.ylabel("Amount Spend",color='black',fontsize=15)
pl.legend()
pl.savefig("big.png",dpi=300,bbox_inches='tight')
pl.show()

# %%
sub=["cs","maths","it"]
boys=[12,34,14]
girls=[20,10,10]
width=0.4
val=np.arange(len(sub))
pl.bar(val,boys,width)
pl.bar(val+0.4,girls,width)
pl.xticks(val+0.2,labels=["hi","hj","jk"])
pl.show()

# %%
pl.style.context("seaborn-v0_8-bright")
pl.figure(figsize=(5,5))
pl.scatter(df[df.Product_Category=="Apparel"]["Product_Category"],df[df.Product_Category=="Apparel"]["Avg_Price"],label="Apparel",color='#c2fce8',s=50)
pl.scatter(df[df.Product_Category=="Housewares"]["Product_Category"],df[df.Product_Category=="Housewares"]["Avg_Price"],label="HouseWares")
pl.scatter(df[df.Product_Category=="Nest-USA"]["Product_Category"],df[df.Product_Category=="Nest-USA"]["Avg_Price"],label="Nest-USA")
pl.scatter(df[df.Product_Category=="Android"]["Product_Category"],df[df.Product_Category=="Android"]["Avg_Price"],label="Android")
pl.title("Prices on Products",fontdict={'fontstyle':'oblique','fontsize':20},color='#d62727',fontweight='bold')
pl.xticks(color="r",rotation=0,fontsize=10)
pl.yticks(color="black",rotation=0,fontsize=10)
pl.xlabel("Category",color='black',fontsize=15)
pl.ylabel("Averages Prices",color='black',fontsize=12)
pl.legend(loc="upper left")
pl.savefig("pricesofproduct.png",dpi=300,bbox_inches='tight')
pl.show()

# %%
pl.style.context("seaborn-v0_8-dark")
pl.bar("Apperel",df[df.Product_Category=="Apparel"]["GST"].mean(),color='#eb8034')
pl.bar("Nest-USA",df[df.Product_Category=="Nest-USA"]["GST"].mean(),color="#c3eb34")
pl.bar("Housewares",df[df.Product_Category=="Housewares"]["GST"].mean(),color="#34eba8")
pl.bar("Android",df[df.Product_Category=="Android"]["GST"].mean())
pl.title("Products GST",fontdict={'fontstyle':'oblique','fontsize':20},color='#d62727',fontweight='bold')
pl.xticks(color="r",rotation=0,fontsize=10)
pl.yticks(color="black",rotation=0,fontsize=10)
pl.xlabel("Products",color='black',fontsize=18)
pl.ylabel("GST Average",color='black',fontsize=15)
pl.savefig("productGST.png",dpi=300,bbox_inches='tight')
pl.show()

# %%
df["Product_Category"].value_counts()
# Out:
# Apparel                 18126
# Nest-USA                14013
# Office                   6513
# Drinkware                3483
# Lifestyle                3092
# Nest                     2198
# Bags                     1882
# Headgear                  771
# Notebooks & Journals      749
# Waze                      554
# Nest-Canada               317
# Bottles                   268
# Accessories               234
# Gift Cards                159
# Housewares                122
# Android                    43
# Name: Product_Category, dtype: int64

# %%
pl.style.context("seaborn-v0_8-bright")
df[["Gender","Offline_Spend"]].groupby("Gender").count().plot(kind='bar',color='#88fc03')
pl.title("Male VS Female online Spend",fontdict={'fontstyle':'oblique','fontsize':20},color='#d62727',fontweight='bold')
pl.text(-0.1,33000,"Female",color='r')
pl.text(0.95,20000,"Male",color='r')
pl.xticks(color="r",rotation=0,fontsize=10)
pl.yticks(color="black",rotation=0,fontsize=10)
pl.xlabel("Gender",color='black',fontsize=15)
pl.ylabel("Offline Spend",color='black',fontsize=15)
pl.legend().remove()
pl.savefig("offliespenmale.png",dpi=300,bbox_inches='tight')
pl.show()

# %%
pl.style.context("seaborn-v0_8-bright")
df[["Gender","Online_Spend"]].groupby("Gender").count().plot(kind='bar',color='#02b2e8')
pl.title("Male VS Female online Spend",fontdict={'fontstyle':'oblique','fontsize':20},color='#d62727',fontweight='bold')
pl.text(-0.1,33000,"Female",color='r')
pl.text(0.95,20000,"Male",color='r')
pl.xticks(color="r",rotation=0,fontsize=10)
pl.yticks(color="black",rotation=0,fontsize=10)
pl.xlabel("Gender",color='black',fontsize=15)
pl.ylabel("Online Spend",color='black',fontsize=15)
pl.legend().remove()
pl.savefig("o1nliespenmale.png",dpi=300,bbox_inches='tight')
pl.show()
